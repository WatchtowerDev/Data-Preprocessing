# %%
from dsio.main import restream_dataframe
from dsio.anomaly_detectors import Percentile1D
import pandas as pd
import numpy as np
import scipy as sp
import plotly
import plotly.figure_factory as ff
import plotly.graph_objs as go
import scipy.signal as ss

# %%
from selfpkg import readDB
from dataFilter import butter_lowpass_filter, butter_highpass_filter

# %%
#function for calculate the time interval between peaks
def freqCal(df, peaksIndex):
    dfTime = df.iloc[peaksIndex] #get sub dataframe 
    prev = dfTime[0: 1] #cache the first 
    for i, _ in dfTime.iteritems():
        cur = dfTime[i] #cache cur
        dfTime[i] = abs(dfTime[i] - prev) #get difference
        prev = cur #set prev from cur (cur val we've cached before)
    return dfTime

# %%
from __future__ import division
from pylab import plot, ylim, xlim, show, xlabel, ylabel, grid
from numpy import linspace, loadtxt, ones, convolve
import numpy as numpy

# %%
def MinToMS(time, df):
    time = time * 60000
    time = df.time.iloc[(df['time']-time).abs().argsort()[:1]] #find the closest time on table
    return time.values[0]

# %%
csv_database = 'sqlite:///SouthHarrison.db' 
df1 = readDB(csv_database)

# %%
cols = [0]
df1.drop(df1.columns[cols],axis=1,inplace=True)

df1.head()
# Out:
#    time   flapper0   flapper1   flapper2  flapper3  flapper4   flapper5  \
# 0  6005  32.250977  25.488281  26.953125  0.488281       0.0  36.425781
# 1  6025  32.250977  25.512695  26.782227  0.537109       0.0  35.961914
# 2  6046  32.299805  25.537109  26.708984  0.488281       0.0  37.475586
# 3  6066  32.373047  25.537109  26.611328  0.585938       0.0  37.475586
# 4  6086  32.324219  25.634766  26.464844  0.781250       0.0  37.475586
#
#     flapper6   flapper7  diameter0  diameter1  orientationX  orientationY  \
# 0  18.994141  21.875000        0.0  10.937500           353            51
# 1  19.018555  21.899414        0.0  10.839844           353            52
# 2  19.018555  21.948242        0.0  10.937500           354            52
# 3  19.091797  21.948242        0.0  10.839844           354            52
# 4  19.091797  21.899414        0.0  10.864258           354            52
#
#    orientationZ  accX  accY  accZ  compassX  compassY  compassZ
# 0           169     5    20    -8       -63       -29        67
# 1           169    -1    15    -4       -64       -26        67
# 2           169     0    17    -2       -64       -26        67
# 3           169    -2    17     0       -64       -29        67
# 4           169     0    16     0       -64       -29        67

# %%
def movingaverage(interval, window_size):
    window= numpy.ones(int(window_size))/float(window_size)
    return numpy.convolve(interval, window, 'same')

start = MinToMS(15, df1)
end = MinToMS(175, df1)

startIndex = df.index[df['time'] == start].tolist()[0]
endIndex = df.index[df['time'] == end].tolist()[0]

x1 = df1.time[startIndex: endIndex]
y1 = df1.flapper0[startIndex: endIndex]

y_av1 = movingaverage(y1, 100)

# %%
trace0 = go.Scattergl(
    x=x1/timeConversionVal,
    y=y1,
    mode = 'markers',
    marker = dict(
        color = ('rgb(127, 127, 127)'),
        size = 3)
)

trace1 = go.Scattergl(
    x=x1/timeConversionVal,
    y=y_av1,
    line = dict(
        color = ('rgb(255, 0, 0)'))
)

data = [trace0, trace1]

layout = dict(title = 'flapper sensor',
                   xaxis = dict(title = 'time'),
                   yaxis = dict(title = 'flapper sensor output'))

fig = dict(data = data, layout = layout)
plotly.offline.plot(fig, filename='test4anomalyDetection.html')
# Out:
# 'file:///Users/meng/Documents/dataPreprocessing/venv/source/test4anomalyDetection.html'

# %%
csv_database = 'sqlite:///SouthHarrison.db' 
df = readDB(csv_database)

# %%
order = 5 #order of filter (1-)
fs = 12.5       # sample rate, Hz
cutoff = 4 # desired cutoff frequency of the filter, Hz

# %%
#function for generate flapper Chart
def flapperChartLowpass(df, start=None, end=None, filename='flapperChartLowpass'):
    
    if start is None:
        start = df.iloc[0]['time'].item()
    else:
        start = MinToMS(start, df)
    if end is None:
        end = df.tail(1)['time'].item()
    else:
        end = MinToMS(end, df)
    
    startIndex = df.index[df['time'] == start].tolist()[0] #get the index of start & end
    endIndex = df.index[df['time'] == end].tolist()[0]
    
    trace0 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal, 
        y=butter_lowpass_filter(df.flapper0[startIndex: endIndex], cutoff, fs, order) + 40,
        name = 'flapper0',
        line = dict(
            color = ('rgb(255, 0, 0)'),
            width = 1)
    )
    trace1 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper1[startIndex: endIndex], cutoff, fs, order) + 30,
        name = 'flapper1',
        line = dict(
            color = ('rgb(0, 255, 0)'),
            width = 1)
    )
    trace2 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper2[startIndex: endIndex], cutoff, fs, order) + 20,
        name = 'flapper2',
        line = dict(
            color = ('rgb(0, 0, 255)'),
            width = 1)
    )
    trace3 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper3[startIndex: endIndex], cutoff, fs, order) + 30,
        name = 'flapper3',
        line = dict(
            color = ('rgb(255, 127, 127)'),
            width = 1)
    )
    trace4 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper4[startIndex: endIndex], cutoff, fs, order) - 10,
        name = 'flapper4',
        line = dict(
            color = ('rgb(255, 0, 255)'),
            width = 1)
    )
    trace5 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper5[startIndex: endIndex], cutoff, fs, order) - 20,
        name = 'flapper5',
        line = dict(
            color = ('rgb(255, 127, 0)'),
            width = 1)
    )
    trace6 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper6[startIndex: endIndex], cutoff, fs, order) - 30,
        name = 'flapper6',
        line = dict(
            color = ('rgb(127, 127, 127)'),
            width = 1)
    )
    trace7 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_lowpass_filter(df.flapper7[startIndex: endIndex], cutoff, fs, order) - 40,
        name = 'flapper7',
        line = dict(
            color = ('rgb(0, 0, 0)'),
            width = 1)
    )

    data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7]

    layout = dict(title = filename,
                       xaxis = dict(title = 'time(minutes)'),
                       yaxis = dict(title = 'friction')
                      )

    fig = dict(data = data, layout = layout)
    plotly.offline.plot(fig, filename = filename + '.html') #offline generate

# %%
start = 79
end = 81
filename = 'flapperLowpassSH'
flapperChartLowpass(df, start, end, filename=filename)

# %%
#function for generate flapper Chart
def flapperChartLowHighpass(df, start=None, end=None, filename='flapperChartLowHighpass'):
    
    if start is None:
        start = df.iloc[0]['time'].item()
    else:
        start = MinToMS(start, df)
    if end is None:
        end = df.tail(1)['time'].item()
    else:
        end = MinToMS(end, df)
    
    startIndex = df.index[df['time'] == start].tolist()[0] #get the index of start & end
    endIndex = df.index[df['time'] == end].tolist()[0]
    
    trace0 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal, 
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper0[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper0',
        line = dict(
            color = ('rgb(255, 0, 0)'),
            width = 1)
    )
    trace1 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper1[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper1',
        line = dict(
            color = ('rgb(0, 255, 0)'),
            width = 1)
    )
    trace2 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper2[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper2',
        line = dict(
            color = ('rgb(0, 0, 255)'),
            width = 1)
    )
    trace3 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper3[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper3',
        line = dict(
            color = ('rgb(255, 255, 0)'),
            width = 1)
    )
    trace4 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper4[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper4',
        line = dict(
            color = ('rgb(255, 0, 255)'),
            width = 1)
    )
    trace5 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper5[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper5',
        line = dict(
            color = ('rgb(255, 127, 0)'),
            width = 1)
    )
    trace6 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper6[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper6',
        line = dict(
            color = ('rgb(127, 127, 127)'),
            width = 1)
    )
    trace7 = go.Scattergl(
        x=df.time[startIndex: endIndex]/timeConversionVal,
        y=butter_highpass_filter(butter_lowpass_filter(df.flapper7[startIndex: endIndex], cutoff, fs, order), cutoff, fs, order),
        name = 'flapper7',
        line = dict(
            color = ('rgb(0, 0, 0)'),
            width = 1)
    )

    data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7]

    layout = dict(title = filename,
                       xaxis = dict(title = 'time(minutes)'),
                       yaxis = dict(title = 'friction')
                      )

    fig = dict(data = data, layout = layout)
    plotly.offline.plot(fig, filename = filename + '.html') #offline generate

# %%
start = 79
end = 81
filename = 'flapperLowHighpassSH'
flapperChartLowHighpass(df, start, end, filename=filename)
